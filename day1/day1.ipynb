# %%
data = [int(i) for i in open("day1_input.csv", "r").read().split("\n")]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-59-02732e3f4657> in <module>
# ----> 1 from ..utils import load_into_list
#       2 data = load_into_list("day1_input.csv")
#       3 # data = [int(i) for i in open("day1_input.csv", "r").read().split("\n")]
#
# ImportError: attempted relative import with no known parent package

# %%
# Part 1
# 
sum([i < j for i, j in zip(data, data[1:])])
# Out:
# 1521

# %%
# Part 2
# Don't need to slide [A, B, C, D] will always have B/C in common
# so only need to compare A and D
sum([i < j for i, j in zip(data, data[3:])])
# Out:
# 1543
